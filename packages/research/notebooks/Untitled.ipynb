# %%
from dotenv import load_dotenv
import dspy
from typing import Literal

# %%
# !pip install dotenv
# Out:
# Collecting dotenv
#   Using cached dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: python-dotenv in /Users/tigran/Desktop/Claude/projects/links-app/packages/research/.venv/lib/python3.14/site-packages (from dotenv) (1.2.2)
# Using cached dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: dotenv
# Successfully installed dotenv-0.9.9
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
load_dotenv()
# Out:
# True

# %%
import os

api_key = os.getenv("ANTHROPIC_API_KEY")

# %%
model_name = "anthropic/claude-haiku-4-5"

lm = dspy.LM(model_name, temperature=1, x_tokens = 100000)
dspy.settings.configure(lm=lm)

# %%
class SupportEmail(dspy.Signature):
    email: str = dspy.InputField()
    subject: str = dspy.OutputField(desc="Subject line of the email")
    priority: Literal["low", "medium", "high"] = dspy.OutputField()
    product: str = dspy.OutputField(desc="The product(s) referenced. Output is an empty strong if unknown.")
    negative_sentiment bool = dspy.OutputField(desc="true/false")

# %%
extract_ticket = dspy.Predict(SupportEmail)
